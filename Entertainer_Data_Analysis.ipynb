# %%
#Importing Necessarylibreries
import pandas as pd

# %%
# Importing Datasets
# Entertainer Basic Info
df_Basic = pd.read_excel( "C:\Entertainer_data_analysis_project\Entertainer - Basic Info.xlsx")

# %%
# View the basic info data of Entertainers
df_Basic.head(10)
# Out:
#        Entertainer Gender (traditional)  Birth Year Profession
# 0            Adele                    F        1988     Singer
# 1   Angelina Jolie                    F        1975      Actor
# 2  Aretha Franklin                    F        1942     Singer
# 3      Bette Davis                    F        1908      Actor
# 4      Betty White                    F        1922      Actor
# 5      Bing Crosby                    M        1903     Singer
# 6         Bob Hope                    M        1903      Actor
# 7    Carol Burnett                    F        1933      Actor
# 8   Carole Lombard                    F        1908      Actor
# 9    Carrie Fisher                    F        1956      Actor

# %%
df_Basic.isnull().sum()  #there is no null values.
# Out:
# Entertainer             0
# Gender (traditional)    0
# Birth Year              0
# Profession              0
# dtype: int64

# %%
df_Basic.describe().T #here we wil get statistical metrics.
# Out:
#             count         mean        std     min     25%     50%     75%  \
# Birth Year   70.0  1935.585714  24.135783  1889.0  1916.0  1935.5  1954.0
#
#                max
# Birth Year  1988.0

# %%
# Import Entertainer_Breakthrough Info
df_Breakthrough = pd.read_excel("C:\Entertainer_data_analysis_project\Entertainer - Breakthrough Info.xlsx")

# %%
df_Breakthrough.head(10)
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
# 5      Bing Crosby                                          1931
# 6         Bob Hope                                          1938
# 7    Carol Burnett                                          1959
# 8   Carole Lombard                                          1934
# 9    Carrie Fisher                                          1977
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...

# %%
df_Breakthrough.isnull().sum()  #there are few null values but those are not important.
# Out:
# Entertainer                                     0
# Year of Breakthrough/#1 Hit/Award Nomination    0
# Breakthrough Name                               0
# Year of First Oscar/Grammy/Emmy                 6
# dtype: int64

# %%
df_Breakthrough.describe().T
# Out:
#                                               count         mean        std  \
# Year of Breakthrough/#1 Hit/Award Nomination   70.0  1964.228571  22.411935
# Year of First Oscar/Grammy/Emmy                64.0  1976.234375  22.170152
#
#                                                  min     25%     50%     75%  \
# Year of Breakthrough/#1 Hit/Award Nomination  1915.0  1949.5  1963.5  1983.5
# Year of First Oscar/Grammy/Emmy               1929.0  1962.0  1978.0  1993.0
#
#                                                  max
# Year of Breakthrough/#1 Hit/Award Nomination  2008.0
# Year of First Oscar/Grammy/Emmy               2017.0

# %%
# Import Entertainer_Last work info
df_Last_work_info = pd.read_excel("C:\Entertainer_data_analysis_project\Entertainer - Last work Info.xlsx")

# %%
df_Last_work_info.head(10)
# Out:
#        Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0            Adele                                2016            NaN
# 1   Angelina Jolie                                2016            NaN
# 2  Aretha Franklin                                2014            NaN
# 3      Bette Davis                                1989         1989.0
# 4      Betty White                                2016            NaN
# 5      Bing Crosby                                1974         1977.0
# 6         Bob Hope                                1972         2003.0
# 7    Carol Burnett                                2016            NaN
# 8   Carole Lombard                                1942         1942.0
# 9    Carrie Fisher                                2016         2016.0

# %%
df_Last_work_info.isnull().sum()  #there are few null values but those are not important.
# Out:
# Entertainer                            0
# Year of Last Major Work (arguable)     0
# Year of Death                         40
# dtype: int64

# %%
# Import Entertainer_Awards info
df_Awards_info = pd.read_excel("C:\Entertainer_data_analysis_project\Enterainer - Awards info.xlsx")

# %%
df_Awards_info.head(10)
# Out:
#        Entertainer Profession Award Won from Breakthrough  Total Awards won  \
# 0            Adele     Singer                      Grammy                32
# 1   Angelina Jolie      Actor                       Oscar                58
# 2  Aretha Franklin     Singer                    No Award                29
# 3      Bette Davis      Actor                    No Award                34
# 4      Betty White      Actor                        Emmy                39
# 5      Bing Crosby     Singer                      Grammy                18
# 6         Bob Hope      Actor                    No Award                39
# 7    Carol Burnett      Actor                        Emmy                49
# 8   Carole Lombard      Actor                    No Award                 1
# 9    Carrie Fisher      Actor                       Other                 7
#
#    Total Nominees  Oscar Won  Grammy Won  Emmy Won  Other Awards
# 0              64          1          15         0             16
# ...

# %%
df_Awards_info.isnull().sum()  #there is no null values.
# Out:
# Entertainer                    0
# Profession                     0
# Award Won from Breakthrough    0
# Total Awards won               0
# Total Nominees                 0
# Oscar Won                      0
# Grammy Won                     0
# Emmy Won                       0
# Other Awards                   0
# dtype: int64
